# %%
results = {'l1_alex_2': 1.0, 'l4_alex_2': 0.2311986729479049, 't1_alex_3': 0.9196180946970622, 't4_alex_4': 0.6022340511177977, 'l1_zf': 1.0, 'l4_zf': 0.3983693921898759, 't1_zf': 0.8601773148314746, 't4_zf': 0.5578533271759605, 'l1_vgg': 1.0, 'l4_vgg': 0.22265116667295015, 't1_vgg': 0.7054588096711291, 't4_vgg': 0.5014616710252313, 'l1_res': 1.0, 'l4_res': 0.28020897760712904, 't1_res': 0.7637973051434935, 't4_res': 0.5288184537370477, 'l1_vgg19': 1.0, 'l4_vgg19': 0.2027392860019075, 't1_vgg19': 0.6889956189655707, 't4_vgg19': 0.49681490942832185}

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
 

alex = [['L1',results['l1_alex_2']], ['T1',results['t1_alex_3']],['T4',results['t4_alex_4']],['L4',results['l4_alex_2']]]
zf = [['L1',results['l1_zf']], ['T1',results['t1_zf']],['T4',results['t4_zf']],['L4',results['l4_zf']]]
vgg16 = [['L1',results['l1_vgg']], ['T1',results['t1_vgg']],['T4',results['t4_vgg']],['L4',results['l4_vgg']]]
vgg19 = [['L1',results['l1_vgg19']], ['T1',results['t1_vgg19']],['T4',results['t4_vgg19']],['L4',results['l4_vgg19']]]
res = [['L1',results['l1_res']], ['T1',results['t1_res']],['T4',results['t4_res']],['L4',results['l4_res']]]
 
alex_df = pd.DataFrame(alex, columns = ['AlexNet', 'Run-Time'])
zf_df = pd.DataFrame(zf, columns = ['ZfNet', 'Run-Time'])
vgg16_df = pd.DataFrame(vgg16, columns = ['VGG16', 'Run-Time'])
vgg19_df = pd.DataFrame(vgg19, columns = ['VGG19', 'Run-Time'])
res_df = pd.DataFrame(res, columns = ['ResNet', 'Run-Time'])
 
f, axs = plt.subplots(1,5,
                      figsize=(15,5),
                      sharey=True)
 
sns.lineplot(data= alex_df,
                x="AlexNet",
                y="Run-Time",
                ax=axs[0],
                marker="o",
                legend=False)
 
 
sns.lineplot(data= zf_df,
                x="ZfNet",
                y="Run-Time",
                ax=axs[1],
                marker="o",
                legend=False)
 
sns.lineplot(data= vgg16_df,
                x="VGG16",
                y="Run-Time",
                ax=axs[2],
                marker="o",
                legend=False)

sns.lineplot(data= vgg19_df,
                x="VGG19",
                y="Run-Time",
                ax=axs[3],
                marker="o",
                legend=False)
 
sns.lineplot(data= res_df,
                x="ResNet",
                y="Run-Time",
                ax=axs[4],
                marker="o",
                legend=False)
 
f.tight_layout()
